# %%
import pandas as pd

# %%
trans = pd.read_excel('/home/philip/fmcg-sales-data-pipeline/data/raw/FMN_data.xlsx', sheet_name='Transactions')
prd = pd.read_excel('/home/philip/fmcg-sales-data-pipeline/data/raw/FMN_data.xlsx', sheet_name='Products')
dist = pd.read_excel('/home/philip/fmcg-sales-data-pipeline/data/raw/FMN_data.xlsx', sheet_name='Distributors')
salesp = pd.read_excel('/home/philip/fmcg-sales-data-pipeline/data/raw/FMN_data.xlsx', sheet_name='Salespersons')
mnthtarg = pd.read_excel('/home/philip/fmcg-sales-data-pipeline/data/raw/FMN_data.xlsx', sheet_name='Monthly_Targets')
date_table = pd.read_excel('/home/philip/fmcg-sales-data-pipeline/data/raw/FMN_data.xlsx', sheet_name='Date_Table')

# %%
trans.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3500 entries, 0 to 3499
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Transaction Id       3500 non-null   str
#  1   Transaction Date     3500 non-null   datetime64[us]
#  2   Product Id           3500 non-null   str
#  3   Distributor Id       3434 non-null   str
#  4   Salesperson Id       3500 non-null   str
#  5   Quantity             3500 non-null   int64
#  6   Unit Price Ngn       3500 non-null   int64
#  7   Discount Pct         3500 non-null   int64
#  8   Discount Amount Ngn  3500 non-null   float64
#  9   Revenue Ngn          3500 non-null   float64
#  10  Cogs Ngn             3500 non-null   int64
#  11  Gross Profit Ngn     3500 non-null   float64
#  12  Payment Method       3500 non-null   str
#  13  Delivery Status      3500 non-null   str
#  14  Transaction Status   3500 non-null   str
# ...

# %%
trans.describe()
# Out:
#                  Transaction Date     Quantity  Unit Price Ngn  Discount Pct  \
# count                        3500  3500.000000     3500.000000   3500.000000
# mean   2024-12-28 03:37:14.057142   100.785429      415.394286      2.774000
# min           2024-01-01 00:00:00     1.000000      100.000000      0.000000
# 25%           2024-06-29 00:00:00    50.000000      200.000000      0.000000
# 50%           2024-12-30 00:00:00   101.000000      350.000000      2.000000
# 75%           2025-06-28 06:00:00   151.000000      500.000000      5.000000
# max           2025-12-31 00:00:00   200.000000     1200.000000     10.000000
# std                           NaN    57.739577      286.710685      3.607264
#
#        Discount Amount Ngn    Revenue Ngn       Cogs Ngn  Gross Profit Ngn
# count          3500.000000    3500.000000    3500.000000       3500.000000
# mean           1150.702829   41222.745743   21302.747143      19919.998600
# ...

# %%
trans['Transaction Id'].value_counts()
# Out:
# Transaction Id
# TXN00001    1
# TXN00002    1
# TXN00003    1
# TXN00004    1
# TXN00005    1
#            ..
# TXN03496    1
# TXN03497    1
# TXN03498    1
# TXN03499    1
# TXN03500    1
# Name: count, Length: 3500, dtype: int64
